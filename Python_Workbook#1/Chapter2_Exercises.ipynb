# %% [markdown]
# # EXERCISE 1

# %% [markdown]
# Write a program that uses input to prompt a user for their name and then welcomes them.
# ```
# Enter your name: Chuck
# Hello Chuck
# ```

# %%
name = input("Enter your name: ")
print(f"Hello {name}")
# Out:
# Enter your name: Chuck
# Hello Chuck

# %% [markdown]
# # EXERCISE 2

# %% [markdown]
# Write a program to prompt the user for hours and rate per hour to compute gross pay.
# ```
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25
# ```

# %%
hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

print(f"Pay: {hours * rate}")
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25

# %% [markdown]
# # EXERCISE 3

# %% [markdown]
# Assume that we execute the following assignment statements:
# ```python
# width = 17
# height = 12.0
# ```
# For each of the following expressions, write the value of the expression and the type (of the value of the expression).
# ```python
# width//2
# width/2.0
# height/3
# 1 + 2 * 5
# ```

# %%
width = 17
height = 12.0

sample1 = width//2
sample2 = width/2.0
sample3 = height/3
sample4 = 1 + 2 * 5

print(f"width//2 is equal to {sample1} and is a {type(sample1)}")
print(f"width/2.0 2 is equal to {sample2} and is a {type(sample2)}")
print(f"height/3 is equal to {sample3} and is a {type(sample3)}")
print(f"1+2*5 is equal to {sample4} and is a {type(sample4)}")
# Out:
# Width is 17 and is a <class 'int'>
# Height is 12.0 and is a <class 'float'>

# %% [markdown]
# # EXERCISE 4

# %% [markdown]
# Write a program that uses input to prompt a user for a number and then outputs the square of the number
# ```
# Enter a number: 3
# The square of 3 is 9
# ```

# %%
number = int(input("Enter a number: "))
print(f"The square of {number} is {number*number}")
# Out:
# Enter a number: 3
# The square of 3 is 9

# %% [markdown]
# # CHALLENGE

# %% [markdown]
# Write a program which prompts the user for a Celsius temperature, convert the temperature to Fahrenheit, and print out the converted temperature.

# %%
celsius = float(input("Enter temperature in Celsius: "))

fahrenheit = celsius * 1.8 + 32

print(f"{celsius} Celsius = {fahrenheit} Fahrenheit")
# Out:
# Enter temperature in Celsius: 5
# 5.0 Celsius = 41.0 Fahrenheit
